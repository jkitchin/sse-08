# %%
from sse_oa import Works

w = Works('https://doi.org/10.1021/acscatal.5b00538')
w
# Out:
# John R. Kitchin, Examples of Effective Data Sharing in Scientific Publishing, 5, 63894-3899, (2015), https://doi.org/10.1021/acscatal.5b00538. cited by: 20. https://openalex.org/W2288114809

# %%
w.ris;
# Out:
# <pre>TY  - JOUR
# AU  - John R. Kitchin
# PY  - 2015
# TI  - Examples of Effective Data Sharing in Scientific Publishing
# JO  - ACS catalysis
# VL  - 5
# IS  - 6
# SP  - 3894
# EP  - 3899
# DO  - https://doi.org/10.1021/acscatal.5b00538
# ER  -</pre><br><a href="..." download="ris">Download RIS</a>
